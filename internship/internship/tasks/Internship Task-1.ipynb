# %% [markdown]
# # Intership Task - 1

# %% [markdown]
# 1. HELLO WORLD

# %%
string = "Hello, World!"
print(string)
# Out:
# Hello, World!

# %% [markdown]
# 2. If -Else

# %%
#Given an integer n, print ‘Weird’ if it is odd or in the range 6–20; and print ‘Not Weird’ when in range 2-5 else when n>20
import math
import os
import random
import re
import sys

if __name__ == '__main__':
    n = int(input().strip())
    
# strip removes extra spaces or newline from the input
if n % 2 == 1:
    print("Weird")
elif 2 <= n <= 5:
    print("Not Weird")
elif 6 <= n <=20:
    print("Weird")
else:
    print("Not Weird")
# Out:
#  5
# Weird

# %% [markdown]
# 3. Arithmetic Operators

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    
print(a+b)
print(a-b)
print(a*b)
# Out:
#  3
#  8
# 11
# -5
# 24

# %% [markdown]
# 4. Division

# %%
#division and remainder
if __name__ == '__main__':
    a = int(input())
    b = int(input())
print(a//b)
print(a/b)
# Out:
#  7
#  9
# 0
# 0.7777777777777778

# %% [markdown]
# 5. Loops

# %%
#Given an integer n, print the square of every number from 0 to n−1 on separate lines
if __name__ == '__main__':
    n = int(input())
    for i in range(n):
        print(i*i)
# Out:
#  12
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121

# %% [markdown]
# 6. Leap year or not

# %%
def is_leap(year):
    leap = False
    if(year%400==0) or (year%4==0 and year%100!=0):
        leap=True
    return leap

year = int(input())
print(is_leap(year))
# Out:
#  2025
# False

# %% [markdown]
# 7. Given an integer n, print all numbers from 1 to n consecutively without spaces (output: 123…n)

# %%
###### if __name__ == '__main__':
    n = int(input())
for i in range(1,n+1):
    print(i,end ='')
# Out:
#  6
# 123456
